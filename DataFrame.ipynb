# %%
import pandas as pd

# %%
# set path to csv
data_file = "glassdoor_listings.csv"

# %%
# use pandas to read file
data_file_read = pd.read_csv(data_file)
data_file_read.head()
# Out:
#                                   _id    company_name         city state  \
# 0  ObjectId(5be52000cf9f4e5350e67766)  Banner Health       Phoenix    AZ
# 1  ObjectId(5be52050cf9f4e5350e67767)  Banner Health       Phoenix    AZ
# 2  ObjectId(5be52055cf9f4e5350e67768)    Wells Fargo       Phoenix    AZ
# 3  ObjectId(5be52059cf9f4e5350e67769)        GoDaddy         Tempe    AZ
# 4  ObjectId(5be5205ccf9f4e5350e6776a)       McKesson    Scottsdale    AZ
#
#      salary_low    salary_high  rating  \
# 0   $73,000.00    $110,000.00      3.4
# 1   $73,000.00    $110,000.00      3.4
# 2   $93,000.00    $133,000.00      3.5
# 3   $77,000.00    $111,000.00      3.5
# 4   $65,000.00     $98,000.00      3.4
#
#                                      job_description
# 0  Careers Center | Data Scientist\nPlease Enable...
# 1  Careers Center | Data Scientist\nPlease Enable...
# 2  Job Description\nAt Wells Fargo, we want to sa...
# 3  About GoDaddy\n\nGoDaddy powers the world's la...
# ...

# %%
data_file_read.count()
# Out:
# _id                4102
# company_name       4102
# city               4102
# state              4102
# salary_low         4102
# salary_high        4102
# rating             4102
# job_description    4102
# dtype: int64

# %%
state_count = data_file_read["state"].value_counts()
print(state_count)
# Out:
#  CA    1279
#  WA     659
#  MA     483
#  TX     440
#  PA     359
#  VA     209
#  DC     184
#  AZ     163
#  OR     157
#  MD      94
#  DE      55
#  NJ      20
# Name: state, dtype: int64

# %%
grouped_city_df = data_file_read.groupby(["city"])
print(grouped_state_df)
grouped_city_df.count()

df.loc('city' in austin_MSA)
austin_MSA = []
# Out:
# ...
#                       _id  company_name  state  salary_low  salary_high  \
# city
#  Alameda                6             6      6           6            6
#  Alexandria            14            14     14          14           14
#  Ambler                 2             2      2           2            2
#  Andover                1             1      1           1            1
#  Annapolis Junction     7             7      7           7            7
#  Arlington             35            35     35          35           35
#  Aston                  1             1      1           1            1
#  Audubon                2             2      2           2            2
#  Austin               209           209    209         209          209
#  Bala Cynwyd            1             1      1           1            1
#  Beaverton             43            43     43          43           43
#  Bedford                3             3      3           3            3
# ...
